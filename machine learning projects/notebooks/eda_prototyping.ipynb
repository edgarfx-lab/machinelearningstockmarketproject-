# %%
# LSTM Stock Price Prediction EDA & Prototyping

import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# Download 5 years of AAPL data
df = yf.download('AAPL', period='5y')
df['Close'].plot(figsize=(12,6), title='AAPL Close Price - 5 Years')
plt.show()

# Display head
df.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-08-05  106.988342  107.309127  105.855881  106.322477  121776800
# 2020-08-06  110.721092  111.216850  106.730753  107.321283  202428800
# 2020-08-07  108.203766  110.699184  107.405232  110.241487  198045600
# 2020-08-10  109.776489  110.796568  107.120390  109.652325  212403600
# 2020-08-11  106.511749  109.537898  106.251250  109.038818  187902400
